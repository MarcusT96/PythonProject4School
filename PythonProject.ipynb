# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#läser in min fil och som tilldelas variabelnamnet "df". 
df_kpif = pd.read_excel("KPIF-stats12month.xlsx")

# %%
# Konvertera "Datum"-kolumnen till datumobjekt. Just nu är datumen namngivna "1987M01" för "1987/01"
# Först ersätter vi "M" med ett mellanslag för att underlätta tolkningen och
# och sedan avgränsar datumet till att bara innefatta år och månad
df_kpif["Datum"] = pd.to_datetime(df_kpif["Datum"].str.replace("M", "-"))
        
# Sätter Datumen till index istället för numeriska värden för bättre läsbarhet   
df_kpif.set_index("Datum", inplace=True)

# %%
value = input("Välj värde: ")

plt.figure(figsize=(15, 6))  # Ställ in storleken på din plot
df_kpif[value].plot(kind="line")  # Får KPIF-värdena som linjediagram
plt.title("KPIF '12 Månaders-utveckling' Utveckling över Tid") #Sätter passande titel
plt.xlabel("Datum") #Har datum på X-axeln
plt.ylabel("KPIF") #Sätter KPIF-värdena på Y-axeln
plt.grid(True) #Lägger till grid så man enklare kan tolka linjen mot Y-axeln
plt.show() #Visar diagrammet
# Out:
# Välj värde: KPIF

# %%
df_property_price = pd.read_excel("Bostadspriser.xlsx")

# %%
df_property_price.set_index("År",inplace=True)

# %%
df_property_price.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='År'>

# %%
df_property_price
# Out:
#       Riket  Stor-Stockholm  Stor-Göteborg  Stor-Malmö
# År
# 1988    154             189            181         157
# 1989    181             224            217         195
# 1990    203             247            242         229
# 1991    217             254            253         258
# 1992    197             217            219         231
# 1993    175             184            189         197
# 1994    183             202            199         208
# 1995    184             206            200         210
# 1996    185             207            201         213
# 1997    198             233            220         230
# 1998    217             269            249         261
# 1999    237             308            274         302
# 2000    263             374            305         346
# 2001    284             411            328         374
# 2002    302             434            351         403
# 2003    322             443            394         445
# 2004    353             475            446         503
# 2005    387             509            505         569
# 2006    431             574            558         647
# 2007    477             657            607         716
# 2008    491             672            628         710
# 2009    501             676            636         718
# 2010    538             741            693         775
# 2011    542             752            709         771
# 2012    535             747            705         736
# 2013    554             778            737         748
# 2014    592             860            782         778
# 2015    656             979            875         849
# 2016    711            1066            922         954
# 2017    770            1125           1022        1051
# 2018    770            1067           1014        1084
# 2019    791            1072           1045        1131
# 2020    843            1139           1098        1223
# 2021    985            1351           1271        1452
# 2022   1029            1399           1311        1491
# 2023    928            1246           1267        1323

# %%
df_bostadsratt = pd.read_excel("bostadsrattspriser.xlsx")

# %%
df_bostadsratt.set_index("År")
# Out:
#       Stor-Stockholm  Stor-Göteborg  Stor-Malmö  Riket exkl storstadsområden
# År
# 2000             720            300         200                           71
# 2001             800            375         240                           85
# 2002             925            480         300                          104
# 2003             925            590         411                          130
# 2004            1020            720         535                          170
# 2005            1130            795         600                          200
# 2006            1350            975         780                          255
# 2007            1625           1160         950                          310
# 2008            1560           1150         895                          350
# 2009            1640           1210         950                          380
# 2010            1750           1340        1030                          445
# 2011            1820           1360         998                          455
# 2012            1895           1415         995                          500
# 2013            2042           1569        1000                          560
# 2014            2300           1710        1075                          650
# 2015            2750           2100        1245                          810
# 2016            3000           2350        1395                          950
# 2017            3100           2600        1600                         1150
# 2018            2900           2500        1610                         1150
# 2019            2950           2520        1700                         1200
# 2020            3120           2650        1850                         1300
# 2021            3313           2850        2095                         1475
# 2022            3350           2800        2125                         1450

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))

# Plotta första DataFrame (df_kpif) på ax1
color = 'tab:blue'
ax1.set_xlabel('Datum')
ax1.set_ylabel('KPIF (%)', color=color)
ax1.plot(df_kpif.index, df_kpif['KPIF'], color="red")
ax1.tick_params(axis='y', labelcolor=color)

# Skapa en andra y-axel för ax1
ax2 = ax1.twinx()  # En andra y-axel som delar samma x-axel
color = 'tab:red'
ax2.set_ylabel('Fastighetspriser', color=color)  # vi redan hanterat ax1, vi använder ax2
ax2.plot(df_property_price.index, df_property_price["Stor-Malmö"], color="blue")
ax2.tick_params(axis='y', labelcolor=color)

# Titel och visa plot
plt.title('KPIF och Fastighetspriser över Tid')
fig.tight_layout()  # För att se till att layouten inte överlappar
plt.grid(True)
plt.show()

# %%
df_kpif.index
# Out:
# DatetimeIndex(['1988-01-01', '1988-02-01', '1988-03-01', '1988-04-01',
#                '1988-05-01', '1988-06-01', '1988-07-01', '1988-08-01',
#                '1988-09-01', '1988-10-01',
#                ...
#                '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01',
#                '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', name='Datum', length=432, freq=None)
