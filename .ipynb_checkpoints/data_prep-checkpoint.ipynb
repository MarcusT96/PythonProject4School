# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#läser in min fil och som tilldelas variabelnamnet "df". 
df_kpif = pd.read_excel("KPIF-stats12month.xlsx")
# Här ersätter vi "M" med ett mellanslag för att underlätta tolkningen
df_kpif["Datum"] = df_kpif["Datum"].str.replace("M","-")

# %%
# Sätter Datumen till index istället för numeriska värden för bättre läsbarhet och funktionallitet
df_kpif.set_index("Datum", inplace=True)

df_kpif.index = pd.to_datetime(df_kpif.index)

# %%
df_property_price = pd.read_excel("Bostadspriser.xlsx")

# %%
df_property_price.set_index("År",inplace=True)

# %%
df_property_price.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='År'>

# %%
df_property_price.index
# Out:
# Index([1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype='int64', name='År')

# %%
df_bostadsratt_kvmpris = pd.read_excel("bostadsrattspriser.xlsx")

# %%
df_bostadsratt.set_index("År",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11292\3969673488.py in ?()
# ----> 1 df_bostadsratt.set_index("År",inplace=True)
#
# D:\Anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['År'] are in the columns"

# %%
df_bostadsratt_kvmpris.index = pd.to_datetime(df_bostadsratt.index.astype(str), format='%Y')

# %%
yearly_median_kpif = df_kpif.groupby(pd.Grouper(freq='Y')).median()

# Optional: Convert the index to just the year as an integer
yearly_median_kpif.index = yearly_median_kpif.index.year

# Display the resulting DataFrame
df_kpif_median = yearly_median_kpif

# %%
#Sparar median KPIF till excel-fil som resten av datafilerna.

#df_kpif_median.to_excel("kpif-stats-medianyear.xlsx",index=True) Kommenterar bort då jag redan sparat den

# %%
df_bostadsratt_kvmpris.index = df_bostadsratt.index.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df_bostadsratt_kvmpris.index = df_bostadsratt.index.year
#
# AttributeError: 'Index' object has no attribute 'year'

# %%
fig, ax1 = plt.subplots()


color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('KPIF (%)', color=color)
ax1.plot(df_kpif_median.index, df_kpif_median['KPIF'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for median prices
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Median Price (SEK)', color=color)


colors = ['blue', 'green', 'orange', 'purple']  
for i, column in enumerate(df_bostadsratt.columns):
    ax2.plot(df_bostadsratt.index, df_bostadsratt[column], color=colors[i], label=column)
ax2.tick_params(axis='y', labelcolor=color)


plt.title('KPIF vs Median Apartment Prices in Sweden')
ax2.legend(title='Regions', loc='upper left')

plt.show()
